# %%
name = "PARAM"

print(name[0])
print(name[0:2])
print(name[0:3])
print(name[0:4])
print(name[0:5])
# Out:
# P
# PA
# PAR
# PARA
# PARAM

# %%
a = 'Paramcgwala'
b = 0

for i in a:
    if i in 'aeiouAEIOU':
        b = b + 1

print('number of vowels in ' ,a , ' is ' ,str(b))
# Out:
# number of vowels in  Paramcgwala  is  4
