# %% [markdown]
# Level 14: Merging, Joining & Relational-Style Operations

# %%
import pandas as pd

# %%
df = pd.read_csv('all_neet_marks_2607.csv')

# %%
# 261. Create a state-level summary DataFrame containing student count and average Marks.

df_261 = df.groupby('state').agg({'Marks':['count','mean']}).reset_index()
print(df_261)
# Out:
#                                state   Marks
#                                        count        mean
# 0   ANDAMAN AND NICOBAR ISLANDS (UT)    1025  192.737561
# 1                     ANDHRA PRADESH   63846  260.971024
# 2                  ARUNACHAL PRADESH    4774  162.896942
# 3                              ASSAM   44273  190.937931
# 4                              BIHAR  136193  188.584457
# 5                     CHANDIGARH(UT)    3530  304.816714
# 6                       CHHATTISGARH   44241  185.636084
# 7        DADRA AND NAGAR HAVELI (UT)    1207  221.932063
# 8                 DAMAN AND DIU (UT)     769  180.239272
# 9                              DELHI   66090  256.136435
# 10                               GOA    4930  196.671805
# 11                           GUJARAT   86952  245.138410
# 12                           HARYANA   54864  261.349810
# 13                  HIMACHAL PRADESH   19064  225.685638
# 14                 JAMMU AND KASHMIR   47553  205.413497
# 15                         JHARKHAND   34404  207.912365
# 16                         KARNATAKA  150897  219.465622
# 17                            KERALA  138546  235.698966
# 18                        LADAKH(UT)     715  166.485315
# 19                  LAKSHADWEEP (UT)     167  150.119760
# 20                    MADHYA PRADESH  130238  174.264999
# 21                       MAHARASHTRA  275245  202.281102
# 22                           MANIPUR    8946  200.175833
# 23                         MEGHALAYA    3757  156.409369
# 24                           MIZORAM    2569  155.139354
# 25                          NAGALAND    3705  172.792713
# 26                            ODISHA   64318  204.629606
# 27                     OUTSIDE-INDIA    4750  250.775789
# 28                    PUDUCHERRY(UT)    5810  196.230637
# 29                            PUNJAB   26573  228.662364
# 30                         RAJASTHAN  193130  280.354518
# 31                            SIKKIM    1444  179.342798
# 32                        TAMIL NADU  153704  220.351702
# 33                         TELANGANA   77892  222.757729
# 34                           TRIPURA    5098  178.175363
# 35                     UTTAR PRADESH  332631  192.716034
# 36                       UTTARAKHAND   21989  216.313793
# 37                       WEST BENGAL  117323  219.478585

# %%
# 262. Create a city-level summary DataFrame containing student count and average Marks.


df_261 = df.groupby('city').agg({'Marks':['count','mean']}).reset_index()
print(df_261)
# Out:
#              city  Marks
#                    count        mean
# 0       ABU DHABI    579  259.312608
# 1        ADILABAD   1785  188.221289
# 2        AGARTALA   4888  178.684943
# 3            AGRA   9785  212.643127
# 4       AHMEDABAD  11659  259.716871
# ..            ...    ...         ...
# 562   WEST SIKKIM    156  208.532051
# 563        YADGIR   1778  157.926884
# 564  YAMUNA NAGAR   1489  211.072532
# 565         YANAM    122  163.540984
# 566      YAVATMAL   3358  174.132817
#
# [567 rows x 3 columns]

# %%
# 263. Merge the state-level summary back into the original DataFrame.

df_263 = df.groupby('state').agg({'Marks':'count'}).reset_index()

df263 = df.merge(df_263,on = 'state',how = 'inner')   # on mai maine bataya hai ki kiske level pay krna hai merge and how mai komn sa join krna hai bataya hai 

print(df261)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       3 df_263 = df.groupby('state').agg({'Marks':'count'}).reset_index()
#       4
#       5 df263 = df.merge(df_263,on = 'state',how = 'inner')   # on mai maine bataya hai ki kiske level pay krna hai merge and how mai komn sa join krna hai bataya hai
#       6
# ----> 7 print(df261)
#
# NameError: name 'df261' is not defined

# %%
# 264. Merge the city-level summary back into the original DataFrame.

df_264 = df.groupby('city').agg({'Marks':'count'}).reset_index()
df264 = df.merge(df_264,on= 'city',how = 'inner')
print(df264)
# Out:
#                                     state        city  \
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
#                       center_name  center_num  Srlno.  Marks_x  Marks_y
# 0        KENDRIYA VIDYALAYA NO. 1      110101       1       46     1025
# 1        KENDRIYA VIDYALAYA NO. 1      110101       2      226     1025
# 2        KENDRIYA VIDYALAYA NO. 1      110101       3      449     1025
# 3        KENDRIYA VIDYALAYA NO. 1      110101       4      424     1025
# 4        KENDRIYA VIDYALAYA NO. 1      110101       5      222     1025
# ...                           ...         ...     ...      ...      ...
# 2333157     CHAKDAHA MODEL SCHOOL      461312     135      279     6083
# 2333158     CHAKDAHA MODEL SCHOOL      461312     136      102     6083
# 2333159     CHAKDAHA MODEL SCHOOL      461312     137       14     6083
# 2333160     CHAKDAHA MODEL SCHOOL      461312     138      179     6083
# 2333161     CHAKDAHA MODEL SCHOOL      461312     139       91     6083
#
# [2333162 rows x 7 columns]

# %%
# 265. Merge a centre-level summary back into the original DataFrame.

df_265 = df.groupby('center_name').agg({'Marks':'count'}).reset_index()
df265 = df.merge(df_265,on= 'center_name',how = 'inner')
print(df264)
# Out:
#                                     state        city  \
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
#                       center_name  center_num  Srlno.  Marks_x  Marks_y
# 0        KENDRIYA VIDYALAYA NO. 1      110101       1       46     1025
# 1        KENDRIYA VIDYALAYA NO. 1      110101       2      226     1025
# 2        KENDRIYA VIDYALAYA NO. 1      110101       3      449     1025
# 3        KENDRIYA VIDYALAYA NO. 1      110101       4      424     1025
# 4        KENDRIYA VIDYALAYA NO. 1      110101       5      222     1025
# ...                           ...         ...     ...      ...      ...
# 2333157     CHAKDAHA MODEL SCHOOL      461312     135      279     6083
# 2333158     CHAKDAHA MODEL SCHOOL      461312     136      102     6083
# 2333159     CHAKDAHA MODEL SCHOOL      461312     137       14     6083
# 2333160     CHAKDAHA MODEL SCHOOL      461312     138      179     6083
# 2333161     CHAKDAHA MODEL SCHOOL      461312     139       91     6083
#
# [2333162 rows x 7 columns]

# %%
# 266. Join state-level statistics to each student record.

df_266 = df.groupby('state').agg({'Marks':'sum'}).reset_index()    # Pehle state-wise statistics (jaise total Marks) nikalo.
df266 = df.merge(df_266,on = 'state' , how = 'left')              # Phir state ke basis par har student ke record ke saath statistics join karo.# Left join se original DataFrame ke saare student records preserve rehte hain.
print(df266)
# Out:
#                                     state        city  \
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
#                       center_name  center_num  Srlno.  Marks_x   Marks_y
# 0        KENDRIYA VIDYALAYA NO. 1      110101       1       46    197556
# 1        KENDRIYA VIDYALAYA NO. 1      110101       2      226    197556
# 2        KENDRIYA VIDYALAYA NO. 1      110101       3      449    197556
# 3        KENDRIYA VIDYALAYA NO. 1      110101       4      424    197556
# 4        KENDRIYA VIDYALAYA NO. 1      110101       5      222    197556
# ...                           ...         ...     ...      ...       ...
# 2333157     CHAKDAHA MODEL SCHOOL      461312     135      279  25749886
# 2333158     CHAKDAHA MODEL SCHOOL      461312     136      102  25749886
# 2333159     CHAKDAHA MODEL SCHOOL      461312     137       14  25749886
# 2333160     CHAKDAHA MODEL SCHOOL      461312     138      179  25749886
# 2333161     CHAKDAHA MODEL SCHOOL      461312     139       91  25749886
#
# [2333162 rows x 7 columns]

# %%
# 267. Join city-level statistics to each student record.

df_267 = df.groupby('city').agg({'Marks':'sum'}).reset_index()  # Pehle city-wise total Marks nikalo.

df267 = df.merge(df_267, on='city', how='left')  # City ke basis par har student ke record ke saath statistics join karo.
# Left join se original DataFrame ke saare student records preserve rehte hain.

print(df267)
# Out:
#                                     state        city  \
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
#                       center_name  center_num  Srlno.  Marks_x  Marks_y
# 0        KENDRIYA VIDYALAYA NO. 1      110101       1       46   197556
# 1        KENDRIYA VIDYALAYA NO. 1      110101       2      226   197556
# 2        KENDRIYA VIDYALAYA NO. 1      110101       3      449   197556
# 3        KENDRIYA VIDYALAYA NO. 1      110101       4      424   197556
# 4        KENDRIYA VIDYALAYA NO. 1      110101       5      222   197556
# ...                           ...         ...     ...      ...      ...
# 2333157     CHAKDAHA MODEL SCHOOL      461312     135      279  1313493
# 2333158     CHAKDAHA MODEL SCHOOL      461312     136      102  1313493
# 2333159     CHAKDAHA MODEL SCHOOL      461312     137       14  1313493
# 2333160     CHAKDAHA MODEL SCHOOL      461312     138      179  1313493
# 2333161     CHAKDAHA MODEL SCHOOL      461312     139       91  1313493
#
# [2333162 rows x 7 columns]

# %%
# 268. Create separate DataFrames for state totals and state averages, then merge them.

# %%
# 269. Create separate DataFrames for city totals and city averages, then merge them.

# %%
# 270. Merge two summaries using state as the key.

# %%
# 271. Merge two summaries using city as the key.

# %%
# 272. Create a centre-to-city mapping DataFrame and join it to student data.

# %%
# 273. Identify records that do not match during a merge using an indicator column.

# %%
# 274. Perform a left merge between student data and state statistics.

# %%
# 275. Perform an inner merge between student data and city statistics.

# %%
# 276. Perform an outer merge between two summary DataFrames.

# %%
# 277. Use merge validation to check whether a state-level merge is one-to-many.

# %%
# 278. Merge state and city summaries to create a combined location report.

# %%
# 279. Compare two summary DataFrames and identify states with changed averages.

# %%
# 280. Create a table containing each state, its average Marks, and national average.

# %%
# | Requirement                         | Join    |
# | ----------------------------------- | ------- |
# | Original DataFrame ke saare records | `left`  |
# | Sirf matching records               | `inner` |
# | Summary ke saare records            | `right` |
# | Dono taraf ke saare records         | `outer` |
