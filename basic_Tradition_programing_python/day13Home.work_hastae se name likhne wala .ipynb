# %%
# P Shape 
print("######")
print("#    #")
print("######")
print("#")
print("#")
# Out:
# ######
# #    #
# ######
# #
# #

# %%
# A Shape

print("    #  ")
print("   #  #")
print("  #     #")
print(" #  ###  #")
print("#         # ")
# Out:
#     #
#    #  #
#   #     #
#  #  ###  #
# #         #

# %%
# R Shape 
print("###### ")
print("#    # ")
print("###### ")
print("#   ##  ")
print("#     ## ")
print("#        #")
# Out:
# ######
# #    #
# ######
# #   ##
# #     ##
# #        #

# %%
# a shape 
print("     #   ")
print("    #  #  ")
print("   #    #  ")
print("  #  ##  #  ")
print(" #        #")
# Out:
#      #
#     #  #
#    #    #
#   #  ##  #
#  #        #

# %%
# M shape

print("#                  #")
print("#  #             #  #")
print("#    #          #   #")
print("#      #      #     #")
print("#        #  #       #")
print("#          #        #")
print("#                   #")
print("#                   #")
print("#                   #")
# Out:
# #                  #
# #  #             #  #
# #    #          #   #
# #      #      #     #
# #        #  #       #
# #          #        #
# #                   #
# #                   #
# #                   #

# %%
print("#########") 
print("##       ")
print("######## ")
print("       # ")
print("       # ")
print("#######  ")
# Out:
# #########
# ##
# ########
#        #
#        #
# #######
