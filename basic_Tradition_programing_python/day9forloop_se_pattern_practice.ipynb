# %%
a = '#'
a*3
# Out:
# '###'

# %%
for i in range (1,10):
    print("#"*i)
# Out:
# #
# ##
# ###
# ####
# #####
# ######
# #######
# ########
# #########

# %%
for i in range(10,0,-1):
      print("#"*i)
# Out:
# ##########
# #########
# ########
# #######
# ######
# #####
# ####
# ###
# ##
# #

# %%
for i in range(1,15):
     print("#"*i)
for param in range(15,0,-1):
    print("#"*param)
# Out:
# #
# ##
# ###
# ####
# #####
# ######
# #######
# ########
# #########
# ##########
# ###########
# ############
# #############
# ##############
# ###############
# ##############
# #############
# ############
# ###########
# ##########
# #########
# ########
# #######
# ######
# #####
# ####
# ###
# ##
# #

# %%
a = 'paramcgwala'
a[3]
# Out:
# 'a'

# %%
a = 'paramcgwala'
a[1:3]
# Out:
# 'ar'

# %%
a = 'paramcgwala' 
a[0:4:2]
# Out:
# 'pr'

# %%
a = 'virat'
a[4:0:-1]
# Out:
# 'tari'

# %%
a = 'virat'
for i in range (1,10):
    print(a[0:i])
# Out:
# v
# vi
# vir
# vira
# virat
# virat
# virat
# virat
# virat

# %%
a = "#"

for i in range(1, 6, 2):
    b = " " * (5 - i) + " ".join(a * i)
    print(b)

for i in range(3, 0, -2):
    b = " " * (5 - i) + " ".join(a * i)
    print(b)
# Out:
#     #
#   # # #
# # # # # #
#   # # #
#     #
