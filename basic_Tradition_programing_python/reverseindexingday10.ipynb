# %%
name = "virat"

print(name[-1:-5:-1])
# Out:
# tari

# %%
name = "virat"

print(name[-1:-5:-1])  # ye hamara reverse  indexing
# Out:
# tari

# %%
a = "virat"
a[-1:-6:-2] + a[0:5:2]
# Out:
# 'trvvrt'

# %%
for i in range(1,11):
   print("4 x", i, "=", 4 * i)
# Out:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
for i in range(10,0,-1):
   print("4 x", i, "=", 4 * i)
# Out:
# 4 x 10 = 40
# 4 x 9 = 36
# 4 x 8 = 32
# 4 x 7 = 28
# 4 x 6 = 24
# 4 x 5 = 20
# 4 x 4 = 16
# 4 x 3 = 12
# 4 x 2 = 8
# 4 x 1 = 4
