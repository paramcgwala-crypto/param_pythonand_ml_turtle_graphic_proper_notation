# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data = pd.read_excel("price_vs_demand.xlsx")

print(data.head())
# Out:
#    Price(X)     revenue
# 0       2.1  168.094501
# 1       3.1  220.776674
# 2       4.1  268.502726
# 3       5.1  312.823322
# 4       6.1  354.593593

# %%
X = data.iloc[:, 0:1]
y = data.iloc[:, 1]

# %%
model = LinearRegression()
model.fit(X, y)

print("Intercept =", model.intercept_)
print("Coefficient =", model.coef_)
# Out:
# Intercept = 131.9848898385266
# Coefficient = [35.25401698]

# %%
y_pred = model.predict(X)

print(y_pred)
# Out:
# [206.01832549 241.27234246 276.52635944 311.78037642 347.03439339
#  382.28841037 417.54242735 452.79644432 488.0504613  523.30447827
#  558.55849525 593.81251223 629.0665292  664.32054618 699.57456315
#  734.82858013 770.08259711 805.33661408 840.59063106]

# %%
plt.scatter(X, y, color="red")
plt.plot(X, y_pred, color="blue")
plt.title("Price vs Revenue")
plt.xlabel("Price")
plt.ylabel("Revenue")
plt.show()

# %%
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
mape = np.mean(np.abs((y - y_pred) / y)) * 100
r2 = r2_score(y, y_pred)

print("MSE :", mse)
print("MAE :", mae)
print("MAPE :", mape)
print("R2 :", r2)
# Out:
# MSE : 240.03410470010897
# MAE : 12.96120532915973
# MAPE : 3.5320909504694895
# R2 : 0.9936034240924368

# %%
elasticity = model.coef_[0] * (X.mean().values[0] / y.mean())

print("Elasticity =", elasticity)
# Out:
# Elasticity = 0.7477856672009989
