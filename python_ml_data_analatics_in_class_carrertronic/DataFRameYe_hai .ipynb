# %%
import pandas as pd

# %%
import pandas as pd

data = {
    'Name': ['Virat', 'Rohit', 'KL'],
    'Surname': ['Kohli', 'Sharma', 'Rahul'],
    'Address': ['London', 'Mumbai', 'Mumbai'],
    'IPL_team': ['RCB', 'MI', 'DC']
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name Surname Address IPL_team
# 0  Virat   Kohli  London      RCB
# 1  Rohit  Sharma  Mumbai       MI
# 2     KL   Rahul  Mumbai       DC

# %%
data = {
    'Name': ['KL', 'Rohit', 'Virat'],
    'Surname': ['Rahul', 'Sharma', 'Kohli'],
    'Address': ['Mumbai', 'Mumbai', 'London'],
    'IPL_team': ['DC', 'MI', 'RCB']
}

# %%
df['Name'].str.upper()
# Out:
# 0    VIRAT
# 1    ROHIT
# 2       KL
# Name: Name, dtype: str

# %%
df['Name'].str.lower()
# Out:
# 0    virat
# 1    rohit
# 2       kl
# Name: Name, dtype: str

# %%
df['Runs'] = [5000,3000,20000]
print(df)
# Out:
#     Name Surname Address IPL_team   Runs
# 0  Virat   Kohli  London      RCB   5000
# 1  Rohit  Sharma  Mumbai       MI   3000
# 2     KL   Rahul  Mumbai       DC  20000

# %%
df['Runs']
# Out:
# 0     5000
# 1     3000
# 2    20000
# Name: Runs, dtype: int64

# %%
df.describe()
# Out:
#                Runs
# count      3.000000
# mean    9333.333333
# std     9291.573243
# min     3000.000000
# 25%     4000.000000
# 50%     5000.000000
# 75%    12500.000000
# max    20000.000000

# %%
df['number_of_centuries'] = [30,20,5]
print(df)
# Out:
#     Name Surname Address IPL_team   Runs  number_of_centuries
# 0  Virat   Kohli  London      RCB   5000                   30
# 1  Rohit  Sharma  Mumbai       MI   3000                   20
# 2     KL   Rahul  Mumbai       DC  20000                    5

# %%
df.describe()
# Out:
#                Runs  number_of_centuries
# count      3.000000             3.000000
# mean    9333.333333            18.333333
# std     9291.573243            12.583057
# min     3000.000000             5.000000
# 25%     4000.000000            12.500000
# 50%     5000.000000            20.000000
# 75%    12500.000000            25.000000
# max    20000.000000            30.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 3 non-null      str
#  1   Surname              3 non-null      str
#  2   Address              3 non-null      str
#  3   IPL_team             3 non-null      str
#  4   Runs                 3 non-null      int64
#  5   number_of_centuries  3 non-null      int64
# dtypes: int64(2), str(4)
# memory usage: 276.0 bytes

# %%
df.iloc[0:]  # isme i ka matlab hai index and loc ka maltab hai location
# Out:
#     Name Surname Address IPL_team   Runs  number_of_centuries
# 0  Virat   Kohli  London      RCB   5000                   30
# 1  Rohit  Sharma  Mumbai       MI   3000                   20
# 2     KL   Rahul  Mumbai       DC  20000                    5

# %%
df.iloc[1:]
# Out:
#     Name Surname Address IPL_team   Runs  number_of_centuries
# 1  Rohit  Sharma  Mumbai       MI   3000                   20
# 2     KL   Rahul  Mumbai       DC  20000                    5

# %%
df.iloc[0,0]
# Out:
# 'Virat'

# %%
df.iloc[[0,1],]
# Out:
#     Name Surname Address IPL_team  Runs  number_of_centuries
# 0  Virat   Kohli  London      RCB  5000                   30
# 1  Rohit  Sharma  Mumbai       MI  3000                   20

# %%
df.iloc[[0,1],[0.1]]
# Out:
#     Name
# 0  Virat
# 1  Rohit

# %%
df.iloc[[1,2],[3,0,4]] #  pehele rows wala dkikhat ahia phir row ko slect kiya hai ahamne  parmeet yaad rakhna bro
# Out:
#   IPL_team   Name   Runs
# 1       MI  Rohit   3000
# 2       DC     KL  20000

# %%
df.loc[[0,1],["Name","Runs"]]
# Out:
#     Name  Runs
# 0  Virat  5000
# 1  Rohit  3000

# %%
df.loc[[2,1,0],["Address","IPL_team","Name"]]
# Out:
#   Address IPL_team   Name
# 2  Mumbai       DC     KL
# 1  Mumbai       MI  Rohit
# 0  London      RCB  Virat

# %%
df.set_index('Name')
# Out:
#       Surname Address IPL_team   Runs  number_of_centuries
# Name
# Virat   Kohli  London      RCB   5000                   30
# Rohit  Sharma  Mumbai       MI   3000                   20
# KL      Rahul  Mumbai       DC  20000                    5

# %%
df1 = df.set_index("Name")

# %%
df1.loc[['Virat',]]
# Out:
#       Surname Address IPL_team  Runs  number_of_centuries
# Name
# Virat   Kohli  London      RCB  5000                   30

# %%
df1.loc[["Virat","KL"],['Runs','IPL_team']]
# Out:
#         Runs IPL_team
# Name
# Virat   5000      RCB
# KL     20000       DC

# %%
df.loc[df['Address']=='Mumbai',]
# Out:
#     Name Surname Address IPL_team   Runs  number_of_centuries
# 1  Rohit  Sharma  Mumbai       MI   3000                   20
# 2     KL   Rahul  Mumbai       DC  20000                    5

# %%
df.loc[df['Runs'] >= 1000,]
# Out:
#     Name Surname Address IPL_team   Runs  number_of_centuries
# 0  Virat   Kohli  London      RCB   5000                   30
# 1  Rohit  Sharma  Mumbai       MI   3000                   20
# 2     KL   Rahul  Mumbai       DC  20000                    5

# %%
df.loc[df['Runs'] > 1000, ['Name', 'Surname']]
# Out:
#     Name Surname
# 0  Virat   Kohli
# 1  Rohit  Sharma
# 2     KL   Rahul

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
singer = {"Name":['Paramcgwala','JordanSandhu','kayvee singh','shubh','dilgjitDosanjh'],
    'Number':["5245658574",'4875945678', '4875945645458','4875954678','6646545945678']



}
