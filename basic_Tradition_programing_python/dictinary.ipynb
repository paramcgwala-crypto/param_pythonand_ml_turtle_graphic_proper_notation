# %%
a = {"name": "Paramcgwala"}

# %%
a["name"]
# Out:
# 'Paramcgwala'

# %%
a = {"list  of students":["param","cgwala","saransing"],"surname of student":["paramcgwala","sidhu","shubh","jordan sandhu"]}

# %%
a["surname of student"]
# Out:
# ['paramcgwala', 'sidhu', 'shubh', 'jordan sandhu']

# %%
a["surname of student"][0]
# Out:
# 'paramcgwala'

# %%
a = {
    'List_of_students': ['Virat', 'Rohit', 'Shubham'],
    'Surname_of_students': ['Kohli', 'Sharma', 'Gill']
}

phonebook = {
    'Virat': {
        'phn_no': 123456677,
        'email_address': 'viratkohli@gmail.com',
        'IPL_team': 'RCB'
    }
}

# %%
phonebook['Rohit'] = {
    'phn_no': 765675767,
    'email_address': 'rohitsharma@gmail.com',
    'IPL_team': 'MI'
}

# %%
phonebook['Paramcgwala'] = {
    'phn_no': 9617422068,
    'email_address': 'Paramcgwala@gmail.com',
    'Singing star ': "Raipur"
}

# %%
phonebook['Paramcgwala']['email_address']
# Out:
# 'Paramcgwala@gmail.com'

# %%
phonebook['Paramcgwala']['email_address']
# Out:
# 'Paramcgwala@gmail.com'

# %%
phonebook['Paramcgwala']['Singing star ']
# Out:
# 'Raipur'

# %%
phonebook['Paramcgwala'] ['phn_no'] = 54646165465

# %%
phonebook['Paramcgwala']['dob'] = '3 may 2005'

# %%
a = {'name': ['param','cgwala'],'surname':['cgwala','saransingh']}

# %%
a.keys()
# Out:
# dict_keys(['name', 'surname'])

# %%
a = {'name': ['param','cgwala'],'surname':['cgwala','saransingh']}

for i in a.keys():
    print(i)
# Out:
# name
# surname

# %%
a = {'name': ['param','cgwala'],'surname':['cgwala','saransingh']}

for i in a.keys():
    print(a[i])
# Out:
# ['param', 'cgwala']
# ['cgwala', 'saransingh']

# %%
a.values()
# Out:
# dict_values([['param', 'cgwala'], ['cgwala', 'saransingh']])

# %%
a = {'name': ['param','cgwala'],'surname':['cgwala','saransingh']}

for i in a.values():
    print(i)
# Out:
# ['param', 'cgwala']
# ['cgwala', 'saransingh']

# %%
a = {'name': ['param','cgwala'],'surname':['cgwala','saransingh']}

for i in a.keys():
    print(i)
# Out:
# name
# surname

# %%
a = {'name': ['param','cgwala'],'surname':['shubh x sidhumossewala','saransingh']}

for i in a.values():
    for name in i:
     print(name)
# Out:
# param
# cgwala
# shubh x sidhumossewala
# saransingh

# %%
for i in a.values():
    for j  in i:
        print(j)
# Out:
# param
# cgwala
# shubh x sidhumossewala
# saransingh

# %%
a = {'name': 'Virat Rohit Kohli'}

for i in a.values():
    for j in i:
        print(j)
# Out:
# V
# i
# r
# a
# t
#
# R
# o
# h
# i
# t
#
# K
# o
# h
# l
# i

# %%
a = {'name': ['Virat', 'Rohit'], 'surname': ['Kohli', 'Sharma']}

for i in a.keys():
    for j in a[i]:
        b = ""
        for k in j:
            b = b + k
            print(b)
# Out:
# V
# Vi
# Vir
# Vira
# Virat
# R
# Ro
# Roh
# Rohi
# Rohit
# K
# Ko
# Koh
# Kohl
# Kohli
# S
# Sh
# Sha
# Shar
# Sharm
# Sharma
