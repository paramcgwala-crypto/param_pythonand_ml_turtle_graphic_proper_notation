# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("all_neet_marks_2607.csv")

# %%
# 1. How many students are present in the dataset
df.shape[0]
# Out:
# 2333162

# %%
df.describe()
# Out:
#          center_num        Srlno.         Marks
# count  2.333162e+06  2.333162e+06  2.333162e+06
# mean   3.224020e+05  2.902341e+02  2.171566e+02
# std    1.049598e+05  2.171436e+02  1.662400e+02
# min    1.101010e+05  1.000000e+00 -1.800000e+02
# 25%    2.602020e+05  1.240000e+02  8.700000e+01
# 50%    3.111190e+05  2.510000e+02  1.630000e+02
# 75%    4.122060e+05  4.080000e+02  3.130000e+02
# max    9.914010e+05  1.968000e+03  7.200000e+02

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2333162 entries, 0 to 2333161
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   state        str
#  1   city         str
#  2   center_name  str
#  3   center_num   int64
#  4   Srlno.       int64
#  5   Marks        int64
# dtypes: int64(3), str(3)
# memory usage: 106.8 MB

# %%
d = (df['Marks'] > 18) & (df['state'] == 'CHHATTISGARH')
print(d)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2333157    False
# 2333158    False
# 2333159    False
# 2333160    False
# 2333161    False
# Length: 2333162, dtype: bool

# %%
df.columns
# Out:
# Index(['state', 'city', 'center_name', 'center_num', 'Srlno.', 'Marks'], dtype='str')

# %%
# 2. How many states are present
df["state"].nunique()
# Out:
# 38

# %%
df[['Marks','city']]
# Out:
#          Marks        city
# 0           46  PORT BLAIR
# 1          226  PORT BLAIR
# 2          449  PORT BLAIR
# 3          424  PORT BLAIR
# 4          222  PORT BLAIR
# ...        ...         ...
# 2333157    279     KALYANI
# 2333158    102     KALYANI
# 2333159     14     KALYANI
# 2333160    179     KALYANI
# 2333161     91     KALYANI
#
# [2333162 rows x 2 columns]

# %%
sum(df['Marks'])
# Out:
# 506661495

# %%
df['Marks'].sum()
# Out:
# np.int64(506661495)

# %%
df['Marks'].max()
# Out:
# np.int64(720)

# %%
df['Marks'].min()
# Out:
# np.int64(-180)

# %%
df.drop_duplicates()
# Out:
#                                     state        city  \
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
#                       center_name  center_num  Srlno.  Marks
# 0        KENDRIYA VIDYALAYA NO. 1      110101       1     46
# 1        KENDRIYA VIDYALAYA NO. 1      110101       2    226
# 2        KENDRIYA VIDYALAYA NO. 1      110101       3    449
# 3        KENDRIYA VIDYALAYA NO. 1      110101       4    424
# ...

# %%
df["city"].nunique()  # tota number of uniwue value batata hai
# Out:
# 567

# %%
df.groupby('state').agg({'Marks':'sum'})
# Out:
#                                      Marks
# state
# ANDAMAN AND NICOBAR ISLANDS (UT)    197556
# ANDHRA PRADESH                    16661956
# ARUNACHAL PRADESH                   777670
# ASSAM                              8453395
# BIHAR                             25683883
# CHANDIGARH(UT)                     1076003
# CHHATTISGARH                       8212726
# DADRA AND NAGAR HAVELI (UT)         267872
# DAMAN AND DIU (UT)                  138604
# DELHI                             16928057
# GOA                                 969592
# GUJARAT                           21315275
# HARYANA                           14338696
# HIMACHAL PRADESH                   4302471
# JAMMU AND KASHMIR                  9768028
# JHARKHAND                          7153017
# KARNATAKA                         33116704
# KERALA                            32655149
# LADAKH(UT)                          119037
# LAKSHADWEEP (UT)                     25070
# MADHYA PRADESH                    22695925
# ...

# %%
df.groupby('state').agg({'Marks':'mean'})
# Out:
#                                        Marks
# state
# ANDAMAN AND NICOBAR ISLANDS (UT)  192.737561
# ANDHRA PRADESH                    260.971024
# ARUNACHAL PRADESH                 162.896942
# ASSAM                             190.937931
# BIHAR                             188.584457
# CHANDIGARH(UT)                    304.816714
# CHHATTISGARH                      185.636084
# DADRA AND NAGAR HAVELI (UT)       221.932063
# DAMAN AND DIU (UT)                180.239272
# DELHI                             256.136435
# GOA                               196.671805
# GUJARAT                           245.138410
# HARYANA                           261.349810
# HIMACHAL PRADESH                  225.685638
# JAMMU AND KASHMIR                 205.413497
# JHARKHAND                         207.912365
# KARNATAKA                         219.465622
# KERALA                            235.698966
# LADAKH(UT)                        166.485315
# LAKSHADWEEP (UT)                  150.119760
# ...

# %%
df.columns
# Out:
# Index(['state', 'city', 'center_name', 'center_num', 'Srlno.', 'Marks'], dtype='str')

# %%
df.groupby(['state','city','center_num']).agg({'Marks':['mean','count']}) # har city ka har state  ka marks ka mean and count nikale hai ya average marks
# Out:
#                                                              Marks
#                                                               mean count
# state                            city       center_num
# ANDAMAN AND NICOBAR ISLANDS (UT) PORT BLAIR 110101      192.112798   461
#                                             110102      192.594360   461
#                                             110103      196.174757   103
# ANDHRA PRADESH                   ANANTAPUR  121201      193.769316   906
#                                             121202      207.425676   592
# ...                                                            ...   ...
# WEST BENGAL                      SURI       461901      220.714660   764
#                                             461902      225.723011   704
#                                             461903      149.867012   579
#                                             461904      151.131148   427
# ...

# %%
df.groupby(['city','center_num']).agg({'Marks':['mean','count']})
# Out:
#                            Marks
#                             mean count
# city      center_num
# ABU DHABI 990301      259.312608   579
# ADILABAD  420901      190.109005   633
#           420902      202.130350   514
#           420903      175.142633   638
# AGARTALA  430101      196.590508   906
# ...                          ...   ...
# YAVATMAL  313407      171.421429   280
#           313408      190.897436   234
#           313409      171.177033   209
#           313410      190.769953   213
#           313411      165.135922   206
#
# [4750 rows x 2 columns]

# %%
df.groupby(['city','center_num']).agg({'center_num':['count'],'Marks':['max','min','mean']}).reset_index()
# Out:
#            city center_num       Marks
#                            count   max min        mean
# 0     ABU DHABI     990301   579   710   5  259.312608
# 1      ADILABAD     420901   633   617 -19  190.109005
# 2      ADILABAD     420902   514   624 -27  202.130350
# 3      ADILABAD     420903   638   642  -8  175.142633
# 4      AGARTALA     430101   906   720 -26  196.590508
# ...         ...        ...   ...   ...  ..         ...
# 4745   YAVATMAL     313407   280   670 -16  171.421429
# 4746   YAVATMAL     313408   234   664  -6  190.897436
# 4747   YAVATMAL     313409   209   623  -1  171.177033
# 4748   YAVATMAL     313410   213   608 -30  190.769953
# 4749   YAVATMAL     313411   206   617 -13  165.135922
#
# [4750 rows x 6 columns]

# %%
df.groupby(['state','city']).agg({'Marks':['max'],'center_num':['nunique']})
# Out:
#                                                    Marks center_num
#                                                      max    nunique
# state                            city
# ANDAMAN AND NICOBAR ISLANDS (UT) PORT BLAIR          680          3
# ANDHRA PRADESH                   ANANTAPUR           653          4
#                                  BHIMAVARAM          682          1
#                                  CHIRALA             667          1
#                                  CHITTOOR            656          3
# ...                                                  ...        ...
# WEST BENGAL                      NORTH 24 PARGANAS   715         12
#                                  PURBA MEDINIPUR     711          7
#                                  SILIGURI            720         10
#                                  SOUTH 24 PARGANAS   705         13
#                                  SURI                695          5
#
# [567 rows x 2 columns]

# %%
df.log[df.groupby(['state']).agg({'Marks':[max]})]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.log[df.groupby(['state']).agg({'Marks':[max]})]
#
# File c:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'log'

# %%
c = df.loc[df['Marks']<0,]
print(c.groupby('state').agg({'center_num':'count'})).sort_values(by='center_num',ascending= False).head(2)
# Out:
#                center_num
# state
# UTTAR PRADESH        1902
# MAHARASHTRA          1785

# %%
c = df.loc[(df['Marks']>=400) & (df['Marks']<=700),]
print(c.groupby('state').agg({'center_num':'count'}).sort_values(by='center_num',ascending= False))
# Out:
#                                   center_num
# state
# RAJASTHAN                              52699
# UTTAR PRADESH                          42775
# MAHARASHTRA                            39575
# TAMIL NADU                             26674
# KERALA                                 25172
# KARNATAKA                              24553
# WEST BENGAL                            20179
# GUJARAT                                16926
# BIHAR                                  16813
# ANDHRA PRADESH                         15381
# DELHI                                  13603
# MADHYA PRADESH                         12831
# TELANGANA                              12450
# HARYANA                                12331
# ODISHA                                  9585
# JAMMU AND KASHMIR                       6090
# ASSAM                                   5494
# JHARKHAND                               4940
# CHHATTISGARH                            4665
# PUNJAB                                  4388
# ...

# %%
c = df.loc[(df['Marks']>=400) | (df['Marks']<=700),]
print(c.groupby('state').agg({'center_num':'count'}).sort_values(by='center_num',ascending= False))
# Out:
#                                   center_num
# state
# UTTAR PRADESH                         332631
# MAHARASHTRA                           275245
# RAJASTHAN                             193130
# TAMIL NADU                            153704
# KARNATAKA                             150897
# KERALA                                138546
# BIHAR                                 136193
# MADHYA PRADESH                        130238
# WEST BENGAL                           117323
# GUJARAT                                86952
# TELANGANA                              77892
# DELHI                                  66090
# ODISHA                                 64318
# ANDHRA PRADESH                         63846
# HARYANA                                54864
# JAMMU AND KASHMIR                      47553
# ASSAM                                  44273
# CHHATTISGARH                           44241
# JHARKHAND                              34404
# PUNJAB                                 26573
# ...

# %%
df['between_400_700']=0

for i in range(len(df)):
    if df['Marks'][i] and  df['Marks'][i] <= 700:
        df['between_400_700'][i] = 1

        new = df.groupby('state').agg({'between_400_700':'sum','center_num':'count'})
        new['pct_of_students'] = new['between_400_700'] /new['center_num']*100
        print(100)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_20680\1638706843.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df['between_400_700'][i] = 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 5
#       1 df['between_400_700']=0
#       2
#       3 for i in range(len(df)):
#       4     if df['Marks'][i] and  df['Marks'][i] <= 700:
# ...

# %%
#Tareeka = 2 
df['between_400_700'] = (df['Marks']>= 400) & (df['Marks']<=700)

# %%
#Tareeka = 3 
d = df.loc[(df['Marks']>= 400)  & (df['Marks']<=700),]

numerator_df = d.groupby('state').agg({'center_num':'count'}).sort_values(by='center_num',ascending= False).reset_index()
denominator_df = df.groupby('state').agg({'center_num':'count'}).sort_values(by='center_num',ascending= False)

# %%
df.columns

# %%
df.head()
# Out:
#                               state        city               center_name  \
# 0  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 1  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 2  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 3  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 4  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
#
#    center_num  Srlno.  Marks
# 0      110101       1     46
# 1      110101       2    226
# 2      110101       3    449
# 3      110101       4    424
# 4      110101       5    222

# %%
df.columns
# Out:
# Index(['state', 'city', 'center_name', 'center_num', 'Srlno.', 'Marks'], dtype='str')

# %%
# Out:
# 0          PORT BLAIR
# 1          PORT BLAIR
# 2          PORT BLAIR
# 3          PORT BLAIR
# 4          PORT BLAIR
#               ...
# 2333157       KALYANI
# 2333158       KALYANI
# 2333159       KALYANI
# 2333160       KALYANI
# 2333161       KALYANI
# Name: city, Length: 2333162, dtype: str

# %%
e = df.loc[df[""]]

# %%
d= df.loc[df['Marks']==720,]
print(c.groupby('city').agg({'Marks':'count'}))
# Out:
#                             Marks
# city
# AGARTALA                        1
# AHMEDABAD                       2
# AKOLA                           1
# ANGAMALY                        1
# BENGALURU- URBAN                2
# BHATINDA                        1
# CHENNAI                         4
# DARBHANGA                       1
# DELHI/NEW DELHI                 1
# HALDWANI                        1
# JAIPUR                          5
# JHUNJHUNU                       1
# KOLKATA                         1
# KOLLAM                          1
# KOTA                            2
# KOTTAYAM                        1
# KOZHIKODE/CALICUT               1
# LUCKNOW                         2
# MADHUBANI                       1
# MANGALURU (MANGALORE)           1
# MUMBAI                          2
# MURSHIDABAD                     1
# NAGPUR                          2
# NAMAKKAL                        3
# NANDED                          1
# NAVI MUMBAI                     1
# ...

# %%
df.groupby(['center_num']).agg({'Marks':['max','min']})
# Out:
#            Marks
#              max min
# center_num
# 110101       680  -5
# 110102       670  10
# 110103       648  11
# 120101       700  -3
# 120102       676  -5
# ...          ...  ..
# 991001       677  29
# 991101       662  20
# 991201       656  11
# 991301       697  -5
# 991401       608  29
#
# [4750 rows x 2 columns]

# %%
df.groupby(['state']).agg({'Marks':['max','min'],'center_num':['nunique'],'city':['nunique']})
# Out:
#                                  Marks      center_num    city
#                                    max  min    nunique nunique
# state
# ANDAMAN AND NICOBAR ISLANDS (UT)   680   -5          3       1
# ANDHRA PRADESH                     720  -89        126      27
# ARUNACHAL PRADESH                  705  -16         11       3
# ASSAM                              715 -102         99      17
# BIHAR                              720 -180        227      35
# CHANDIGARH(UT)                     715    0          4       1
# CHHATTISGARH                       711  -44         96      19
# DADRA AND NAGAR HAVELI (UT)        692  -10          4       1
# DAMAN AND DIU (UT)                 665   -4          2       2
# DELHI                              720  -36        116       1
# GOA                                697  -35         16       2
# GUJARAT                            720 -149        184      31
# HARYANA                            716  -96        128      19
# ...

# %%
df.groupby(['state']).agg({'Marks':['max','min'],'center_num':['nunique']})

# %%
df.groupby(['state','city']).agg({'Marks':['mean']})
# Out:
#                                                          Marks
#                                                           mean
# state                            city
# ANDAMAN AND NICOBAR ISLANDS (UT) PORT BLAIR         192.737561
# ANDHRA PRADESH                   ANANTAPUR          197.060985
#                                  BHIMAVARAM         199.756728
#                                  CHIRALA            202.297830
#                                  CHITTOOR           174.487047
# ...                                                        ...
# WEST BENGAL                      NORTH 24 PARGANAS  226.512949
#                                  PURBA MEDINIPUR    191.416456
#                                  SILIGURI           216.213010
#                                  SOUTH 24 PARGANAS  192.899645
#                                  SURI               191.236813
#
# [567 rows x 1 columns]

# %%
df.groupby('state').agg({'Marks':len})
# Out:
#                                    Marks
# state
# ANDAMAN AND NICOBAR ISLANDS (UT)    1025
# ANDHRA PRADESH                     63846
# ARUNACHAL PRADESH                   4774
# ASSAM                              44273
# BIHAR                             136193
# CHANDIGARH(UT)                      3530
# CHHATTISGARH                       44241
# DADRA AND NAGAR HAVELI (UT)         1207
# DAMAN AND DIU (UT)                   769
# DELHI                              66090
# GOA                                 4930
# GUJARAT                            86952
# HARYANA                            54864
# HIMACHAL PRADESH                   19064
# JAMMU AND KASHMIR                  47553
# JHARKHAND                          34404
# KARNATAKA                         150897
# KERALA                            138546
# LADAKH(UT)                           715
# LAKSHADWEEP (UT)                     167
# MADHYA PRADESH                    130238
# MAHARASHTRA                       275245
# ...

# %%
df.groupby(['state','city']).agg({'center_num':'nunique'})
# Out:
#                                                     center_num
# state                            city
# ANDAMAN AND NICOBAR ISLANDS (UT) PORT BLAIR                  3
# ANDHRA PRADESH                   ANANTAPUR                   4
#                                  BHIMAVARAM                  1
#                                  CHIRALA                     1
#                                  CHITTOOR                    3
# ...                                                        ...
# WEST BENGAL                      NORTH 24 PARGANAS          12
#                                  PURBA MEDINIPUR             7
#                                  SILIGURI                   10
#                                  SOUTH 24 PARGANAS          13
#                                  SURI                        5
#
# [567 rows x 1 columns]

# %%
df.groupby(['state','city']).agg({'center_num':'nunique'})

# %%
df[["state","city"]]
# Out:
#                                     state        city
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4        ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...                                   ...         ...
# 2333157                       WEST BENGAL     KALYANI
# 2333158                       WEST BENGAL     KALYANI
# 2333159                       WEST BENGAL     KALYANI
# 2333160                       WEST BENGAL     KALYANI
# 2333161                       WEST BENGAL     KALYANI
#
# [2333162 rows x 2 columns]

# %%
df[["city","state","center_num"]]
# Out:
#                city                             state  center_num
# 0        PORT BLAIR  ANDAMAN AND NICOBAR ISLANDS (UT)      110101
# 1        PORT BLAIR  ANDAMAN AND NICOBAR ISLANDS (UT)      110101
# 2        PORT BLAIR  ANDAMAN AND NICOBAR ISLANDS (UT)      110101
# 3        PORT BLAIR  ANDAMAN AND NICOBAR ISLANDS (UT)      110101
# 4        PORT BLAIR  ANDAMAN AND NICOBAR ISLANDS (UT)      110101
# ...             ...                               ...         ...
# 2333157     KALYANI                       WEST BENGAL      461312
# 2333158     KALYANI                       WEST BENGAL      461312
# 2333159     KALYANI                       WEST BENGAL      461312
# 2333160     KALYANI                       WEST BENGAL      461312
# 2333161     KALYANI                       WEST BENGAL      461312
#
# [2333162 rows x 3 columns]

# %%
df[['Marks', 'Srlno.', 'center_num', 'center_name', 'city', 'state']]
# Out:
#          Marks  Srlno.  center_num               center_name        city  \
# 0           46       1      110101  KENDRIYA VIDYALAYA NO. 1  PORT BLAIR
# 1          226       2      110101  KENDRIYA VIDYALAYA NO. 1  PORT BLAIR
# 2          449       3      110101  KENDRIYA VIDYALAYA NO. 1  PORT BLAIR
# 3          424       4      110101  KENDRIYA VIDYALAYA NO. 1  PORT BLAIR
# 4          222       5      110101  KENDRIYA VIDYALAYA NO. 1  PORT BLAIR
# ...        ...     ...         ...                       ...         ...
# 2333157    279     135      461312     CHAKDAHA MODEL SCHOOL     KALYANI
# 2333158    102     136      461312     CHAKDAHA MODEL SCHOOL     KALYANI
# 2333159     14     137      461312     CHAKDAHA MODEL SCHOOL     KALYANI
# 2333160    179     138      461312     CHAKDAHA MODEL SCHOOL     KALYANI
# 2333161     91     139      461312     CHAKDAHA MODEL SCHOOL     KALYANI
#
#                                     state
# 0        ANDAMAN AND NICOBAR ISLANDS (UT)
# ...

# %%
df.head()
# Out:
#                               state        city               center_name  \
# 0  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 1  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 2  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 3  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 4  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
#
#    center_num  Srlno.  Marks
# 0      110101       1     46
# 1      110101       2    226
# 2      110101       3    449
# 3      110101       4    424
# 4      110101       5    222

# %%
df.tail()
# Out:
#                state     city            center_name  center_num  Srlno.  \
# 2333157  WEST BENGAL  KALYANI  CHAKDAHA MODEL SCHOOL      461312     135
# 2333158  WEST BENGAL  KALYANI  CHAKDAHA MODEL SCHOOL      461312     136
# 2333159  WEST BENGAL  KALYANI  CHAKDAHA MODEL SCHOOL      461312     137
# 2333160  WEST BENGAL  KALYANI  CHAKDAHA MODEL SCHOOL      461312     138
# 2333161  WEST BENGAL  KALYANI  CHAKDAHA MODEL SCHOOL      461312     139
#
#          Marks
# 2333157    279
# 2333158    102
# 2333159     14
# 2333160    179
# 2333161     91

# %%
df.iloc[0,5]
# Out:
# np.int64(46)

# %%
df.iloc[0,[3,5]]
# Out:
# center_num    110101
# Marks             46
# Name: 0, dtype: int64

# %%
df.iloc[[0,1],[1,2]]
# Out:
#          city               center_name
# 0  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1
# 1  PORT BLAIR  KENDRIYA VIDYALAYA NO. 1

# %%
df.iloc[[2,5,8],[5]]
# Out:
#    Marks
# 2    449
# 5    181
# 8     88

# %%
df.loc[[0,10,100,1000,10000],['state','city','Marks']]
# Out:
#                                   state        city  Marks
# 0      ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR     46
# 10     ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR    322
# 100    ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR      5
# 1000   ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR     73
# 10000                    ANDHRA PRADESH     NELLORE    458

# %%
df.loc[df['state'] == 'CHHATTISGARH']
# Out:
#                state               city                     center_name  \
# 253641  CHHATTISGARH  BHILAI NAGAR/DURG   SHRI SHANKARACHARYA VIDYALAYA
# 253642  CHHATTISGARH  BHILAI NAGAR/DURG   SHRI SHANKARACHARYA VIDYALAYA
# 253643  CHHATTISGARH  BHILAI NAGAR/DURG   SHRI SHANKARACHARYA VIDYALAYA
# 253644  CHHATTISGARH  BHILAI NAGAR/DURG   SHRI SHANKARACHARYA VIDYALAYA
# 253645  CHHATTISGARH  BHILAI NAGAR/DURG   SHRI SHANKARACHARYA VIDYALAYA
# ...              ...                ...                             ...
# 297877  CHHATTISGARH       MANENDRAGARH  DELHI WORLD PUBLIC SCHOOL MDGR
# 297878  CHHATTISGARH       MANENDRAGARH  DELHI WORLD PUBLIC SCHOOL MDGR
# 297879  CHHATTISGARH       MANENDRAGARH  DELHI WORLD PUBLIC SCHOOL MDGR
# 297880  CHHATTISGARH       MANENDRAGARH  DELHI WORLD PUBLIC SCHOOL MDGR
# 297881  CHHATTISGARH       MANENDRAGARH  DELHI WORLD PUBLIC SCHOOL MDGR
#
#         center_num  Srlno.  Marks
# 253641      170101       1     58
# ...

# %%
state = []

for i in df["state"]:
    if i not in state:
        state.append(i)
len(state)
# Out:
# 38

# %%
city  = []

for i in df["city"]:
    if i not in  city:
        city.append(i)
len(city)
# Out:
# 567

# %%
print(df.loc[df["city"] == "Mumbai"].shape) #ye bata raha hai ki kiya city mai mumbai bhi hai
# Out:
# (0, 6)

# %%
print(df.loc[df["state"] == "Chhattisgarh"].shape)   # ye bata raha hai  ki state mai chhattisgrah hai
# Out:
# (0, 6)

# %%
print(df["state"].unique()) # ye sab unique stae bata raha  hai
# Out:
# <StringArray>
# ['ANDAMAN AND NICOBAR ISLANDS (UT)',                   'ANDHRA PRADESH',
#                 'ARUNACHAL PRADESH',                            'ASSAM',
#                             'BIHAR',                   'CHANDIGARH(UT)',
#                      'CHHATTISGARH',      'DADRA AND NAGAR HAVELI (UT)',
#                'DAMAN AND DIU (UT)',                            'DELHI',
#                               'GOA',                          'GUJARAT',
#                           'HARYANA',                 'HIMACHAL PRADESH',
#                 'JAMMU AND KASHMIR',                        'JHARKHAND',
#                         'KARNATAKA',                           'KERALA',
#                        'LADAKH(UT)',                 'LAKSHADWEEP (UT)',
#                    'MADHYA PRADESH',                      'MAHARASHTRA',
#                           'MANIPUR',                        'MEGHALAYA',
#                           'MIZORAM',                         'NAGALAND',
# ...

# %%
print(df["state"].nunique())   # ye sare number of unique value bata raha hai
# Out:
# 38

# %%
print(df["city"].unique)    #ye sab unique city bat arahahi hamre dataset ka
# Out:
# <bound method Series.unique of 0          PORT BLAIR
# 1          PORT BLAIR
# 2          PORT BLAIR
# 3          PORT BLAIR
# 4          PORT BLAIR
#               ...
# 2333157       KALYANI
# 2333158       KALYANI
# 2333159       KALYANI
# 2333160       KALYANI
# 2333161       KALYANI
# Name: city, Length: 2333162, dtype: str>

# %%
print(df["city"].nunique) #  ye total numebr of unique value bata  rahah hai
# Out:
# <bound method IndexOpsMixin.nunique of 0          PORT BLAIR
# 1          PORT BLAIR
# 2          PORT BLAIR
# 3          PORT BLAIR
# 4          PORT BLAIR
#               ...
# 2333157       KALYANI
# 2333158       KALYANI
# 2333159       KALYANI
# 2333160       KALYANI
# 2333161       KALYANI
# Name: city, Length: 2333162, dtype: str>

# %%
cities = df.loc[df["state"] == "Chhattisgarh", "city"].unique()

print(len(cities))
# Out:
# 0

# %%
print(df.loc[df["city"] == "Raipur", "center_name"].nunique())
# Out:
# 0

# %%
df.loc[df["state"] == "CHHATTISGARH", "center_num"].nunique()
# Out:
# 96

# %%
df.loc[df["state"] == "CHHATTISGARH", "city"].unique()
# Out:
# <StringArray>
# ['BHILAI NAGAR/DURG',     'BILASPUR (CG)',            'RAIPUR',
#          'AMBIKAPUR',             'BALOD',           'BIJAPUR',
#          'DANTEWADA',          'DHAMTARI',         'JAGDALPUR',
#            'JANJGIR',            'KANKER',         'KONDAGAON',
#              'KORBA',        'MAHASAMUND',        'NARAYANPUR',
#            'RAIGARH',       'RAJNANDGAON',             'SUKMA',
#       'MANENDRAGARH']
# Length: 19, dtype: str

# %%
df.loc[df["city"] == "RAIPUR", "center_num"].nunique()
# Out:
# 17

# %%
print(df.loc[df["state"] == "OUTSIDE-INDIA", "city"].unique())
# Out:
# <StringArray>
# [ 'KUWAIT CITY',        'DUBAI',    'ABU DHABI',      'BANGKOK',
#       'COLOMBO',         'DOHA',    'KATHMANDU', 'KUALA LUMPUR',
#         'LAGOS',       'MANAMA',       'MUSCAT',       'RIYADH',
#       'SHARJAH',    'SINGAPORE']
# Length: 14, dtype: str

# %%
print(df.loc[df["state"] == "INDIA", "city"].unique())
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %%
print(df.loc[df["state"] != "OUTSIDE-INDIA"].shape)
# Out:
# (2328412, 6)

# %%
df.columns
# Out:
# Index(['state', 'city', 'center_name', 'center_num', 'Srlno.', 'Marks'], dtype='str')

# %%
print(df.loc[df['Marks'] < 0, 'Marks'].count())
# Out:
# 9477

# %%
print(df['Marks'].max())
# Out:
# 720

# %%
df.loc[df['Marks'] == max(df['Marks'])].shape
# Out:
# (61, 6)

# %%
print(df.loc[df['Marks'] == max(df['Marks'])].shape)
# Out:
# (61, 6)

# %%
df.loc[(df['Marks'] >= 715) & (df['Marks'] <= 720)].shape
# Out:
# (288, 6)

# %%
counter = 0

for i in df['Marks']:
    if i >= 715 and i <= 720:
        counter = counter + 1

print(counter)
# Out:
# 288

# %%
(df.loc[(df['Marks'] > 700) & (df['Marks'] < 720)].shape[0] / df.shape[0]) * 100
# Out:
# 0.06746209650251461

# %%
#5. What percentage students scored between 700 to 720?
df.loc[(df['Marks'] < 100) | (df['Marks'] > 700)].shape[0]    # ye or ka symbol hai
# Out:
# 695092

# %%
#7. How many students from Chhattisgarh scored between 700 and 720?
df.loc[(df['state'] == 'Chhattisgarh') & (df['Marks'] >= 700) & (df['Marks'] <= 720)].shape[0]
# Out:
# 0

# %%
#8.How many students out of India scored between 700 and 720?
df.loc[(df['state'] != 'Chhattisgarh') & (df['Marks'] >= 700) & (df['Marks'] <= 720)].shape[0]
# Out:
# 2321
