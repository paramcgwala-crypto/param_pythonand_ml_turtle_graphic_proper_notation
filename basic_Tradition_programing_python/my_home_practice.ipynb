# %%
# 16. Count how many numbers greater than 50 are present in the list.
# Do not use len().
numbers = [23, 67, 12, 89, 45, 72, 34, 91]

count = 0 

for i in numbers:
     if i >= 50:
        count += 1 
        

print(count)
# Out:
# 4

# %%
numbers = [23, 67, 12, 89, 45, 72, 34, 91]

count = 0 

for i in  numbers:
     if i > 50:
        count+=1

print(count)
# Out:
# 4

# %%
numbers = [23, 67, 12, 89, 45, 72, 34, 91]

even = []

for num in  numbers:
    if num % 2 == 0:
     even.append(num)

print("Even number list = ",even)
# Out:
# Even number list =  [12, 72, 34]

# %%
numbers = [23, 67, 12, 89, 45, 72, 34, 91]

count = 0   # i aasuming the zero is big 

for i in numbers:
    if num % 2 == 0:
       count += 1 

print("count of even numebr = ",count,"ye hi toh hai count of even numebr")
# Out:
# count of even numebr =  0 ye hi toh hai count of even numebr

# %%
numbers = [23, 67, 12, 89, 45, 72, 34, 91]

largest = numbers[0]
second_largest = numbers[0]

for i in numbers:
     if i > largest:
        second_largest = largest
        largest = i 

     elif i > second_largest:
        i!= largest
        second_largest = i 

print("Second largest number ", second_largest)
# Out:
# Second largest number  89
